# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.array([1, 2, 3])
plt.plot(x, x**2)
plt.show()

# %%
x = np.linspace(1, 3, 100)
plt.plot(x, x**2)
plt.show()

# %%
x = np.linspace(-10000, 10000, 100)
plt.plot(x, x**2)
plt.show()

# %%
x = np.linspace(-10, 10, 1000)
plt.plot(x, x**2)
plt.show()

# %%
g=9.81

# %%
deg_angle=45
angle=(deg_angle/360)*(2*np.pi)
constv0=10
v0h=np.cos(angle)*constv0
v0y=np.sin(angle)*constv0
v0=np.linspace(10,30,5) 
vv0y=np.sin(angle)*v0

# %%
tlim=(2*v0y)/g
t=np.linspace(0,tlim,100)

# %%
distance=v0h*t
h=v0y*t-(0.5*g*(t**2))

# %%
plt.plot(t,h)
plt.show()
print(f"Angle:{round(deg_angle,2)} degrees")
print(f"Initial Velocity:{constv0} m/s")
# Out:
# Angle:45 degrees
# Initial Velocity:10 m/s

# %%
vtlim=(2*vv0y)/g
vt=np.linspace(0,vtlim,100)

# %%
vh=vv0y*vt-(0.5*g*(vt**2))

# %%
plt.plot(vt,vh)
plt.show()
print(f"Angle:{round(deg_angle,2)} degrees")
print(f"Initial Velocity:{v0} m/s")
# Out:
# Angle:45 degrees
# Initial Velocity:[10. 15. 20. 25. 30.] m/s
